# %%
# %sql
-- select count(*) from intellibicatalogo.intellibi_bronze.dfmonthlysales;
-- select count(*) from intellibicatalogo.intellibi_silver.dfmonthlysales;
-- select count(*) from intellibicatalogo.intellibi_gold.dfmonthlysales;

# %%
# %sql
select count(*) from intellibicatalogo.intellibi_gold.dfmonthlysales; -- 160
-- truncate table intellibicatalogo.intellibi_gold.dfmonthlysales;

# %%
# %sql
-- select count(*) from intellibicatalogo.intellibi_silver.dfmonthlysales; -- 160
-- truncate table intellibicatalogo.intellibi_silver.dfmonthlysales;

# %%
# %sql
-- select count(*) from intellibicatalogo.intellibi_bronze.dfmonthlysales; -- 80
-- truncate table intellibicatalogo.intellibi_bronze.dfmonthlysales;
