-- %%
TRUNCATE TABLE intellibicatalogo.intellibi_bronze.rawMonthlySales;
TRUNCATE TABLE intellibicatalogo.intellibi_silver.cleanedMonthlySales;
TRUNCATE TABLE intellibicatalogo.intellibi_gold.refinedMonthlySales;

SELECT * FROM intellibicatalogo.intellibi_bronze.rawMonthlySales;
SELECT * FROM intellibicatalogo.intellibi_silver.cleanedMonthlySales;
SELECT * FROM intellibicatalogo.intellibi_gold.refinedMonthlySales;
