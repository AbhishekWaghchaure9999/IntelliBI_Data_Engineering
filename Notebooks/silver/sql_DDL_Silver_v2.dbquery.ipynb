-- %%
-- CREATE OR REPLACE TABLE intellibi_catalog.intellibi_silver.cleanedPersons
-- (
--     person_name string,
--     age integer,
--     gender string,
--     city string,
--     ingest_ts timestamp
-- );

select * from intellibi_catalog.intellibi_silver.cleanedPersons;

-- describe intellibi_catalog.intellibi_silver.cleanedPersons;
-- describe history intellibi_catalog.intellibi_silver.cleanedPersons;
-- drop table intellibi_catalog.intellibi_silver.cleanedPersons;
-- TRUNCATE TABLE intellibi_catalog.intellibi_silver.cleanedPersons;

update intellibi_catalog.intellibi_silver.cleanedPersons set CITY = 'PUNE' WHERE person_name = 'AARAV SHARMA';
