-- %%
-- CREATE OR REPLACE TABLE intellibi_catalog.intellibi_silver.cleanedCustomer
-- (
--     customer_id INTEGER,
--     customer_name STRING,
--     email STRING,
--     phone STRING,
--     address STRING,
--     city STRING,
--     state STRING,
--     country STRING,
--     zip_code STRING,
--     segment STRING,
--     INGEST_TS TIMESTAMP
-- );

select * from intellibi_catalog.intellibi_silver.cleanedCustomer;
-- describe intellibi_catalog.intellibi_silver.cleanedCustomer;
-- describe history intellibi_catalog.intellibi_silver.cleanedCustomer;
-- TRUNCATE TABLE intellibi_catalog.intellibi_silver.cleanedCustomer;
-- drop table intellibi_catalog.intellibi_silver.cleanedCustomer;

INSERT INTO intellibi_catalog.intellibi_silver.cleanedCustomer (customer_id, customer_name, email, phone, address, city, state, country, zip_code, segment, ingest_ts) VALUES (1011, 'RAHUL VERMA', 'RAHUL.VERMA@EXAMPLE.COM', '+91-9876522222', '55 PARK STREET', 'KOLKATA', 'WB', 'IN', '700016', 'PREMIUM', CURRENT_TIMESTAMP());
