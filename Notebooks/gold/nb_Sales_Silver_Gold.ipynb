# %%
# %sql
MERGE INTO intellibicatalogo.intellibi_gold.dfmonthlysales
USING intellibicatalogo.intellibi_silver.dfmonthlysales
on intellibicatalogo.intellibi_gold.dfmonthlysales.Customer_ID = intellibicatalogo.intellibi_silver.dfmonthlysales.Customer_ID
when matched then update set *
when not matched then insert *;

# %%
# %sql
# -- first create the table in gold laver (2)
# -- CHECK WHETHER THE EMPTY TABLE IS CREATED OR NOT (3)
# -- perform the merge operation (4)
# -- CHECK DATA IN GOLD LAYER (5)
# -- so that we can perform the SCD Type1 opertion
# -- SCD Type1: Upsert(): Update or insert: or: Merge

# %%
# %sql
# CREATE TABLE intellibicatalogo.intellibi_gold.dfmonthlysales
# AS SELECT * FROM intellibicatalogo.intellibi_silver.dfmonthlysales WHERE 1=2;

# %%
# %sql
# SELECT * FROM intellibicatalogo.intellibi_gold.dfmonthlysales;

# %%
# %sql
# SELECT * FROM intellibicatalogo.intellibi_gold.dfmonthlysales;
