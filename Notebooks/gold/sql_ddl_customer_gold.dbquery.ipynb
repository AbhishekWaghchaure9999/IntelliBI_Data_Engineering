-- %%
-- CREATE OR REPLACE TABLE intellibi_catalog.intellibi_gold.refinedCustomer
-- (   
--     customer_sk BIGINT GENERATED ALWAYS AS IDENTITY,
--     customer_id INTEGER,
--     customer_name STRING,
--     email STRING,
--     phone STRING,
--     address STRING,
--     city STRING,
--     state STRING,
--     country STRING,
--     zip_code STRING,
--     segment STRING,
--     INGEST_TS TIMESTAMP,
    -- is_active STRING,
    -- rec_version INTEGER,
    -- start_effective_date TIMESTAMP,
    -- end_effective_date TIMESTAMP
-- );

-- select * from intellibi_catalog.intellibi_gold.refinedCustomer;
-- describe intellibi_catalog.intellibi_gold.refinedCustomer;
-- describe history intellibi_catalog.intellibi_gold.refinedCustomer;
-- TRUNCATE TABLE intellibi_catalog.intellibi_gold.refinedCustomer;
-- drop table intellibi_catalog.intellibi_gold.refinedCustomer;
-- delete from intellibi_catalog.intellibi_gold.refinedCustomer WHERE CUSTOMER_ID IN ('1002', '1003');

INSERT INTO intellibi_catalog.intellibi_gold.RefinedCustomer
(customer_id, customer_name, email, phone, address, city, state, country, zip_code, segment, is_active, rec_version, start_effective_date, end_effective_date)
VALUES
(1011, 'RAHUL BHAU VERMA', 'RAHUL.VERMA@YAHOO.COM', '+91-9876522223', '55 PARK STREET', 'KOLKATA', 'WB', 'IN', '700016', 'PREMIUM', 'Y', 1, CURRENT_TIMESTAMP(), TO_DATE('3099-12-31', 'yyyy-MM-dd'));
