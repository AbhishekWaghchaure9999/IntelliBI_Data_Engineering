-- %%
CREATE OR REPLACE TABLE intellibi_catalog.intellibi_gold.refinedPersons
(
    person_name string,
    age integer,
    gender string,
    city string,
    intial_load_ts timestamp,
    last_update_ts timestamp
);  

select * from intellibi_catalog.intellibi_gold.refinedPersons;

-- describe intellibi_catalog.intellibi_gold.refinedPersons;
-- describe history intellibi_catalog.intellibi_gold.refinedPersons;
-- drop table intellibi_catalog.intellibi_gold.refinedPersons;
-- TRUNCATE TABLE intellibi_catalog.intellibi_gold.refinedPersons;
