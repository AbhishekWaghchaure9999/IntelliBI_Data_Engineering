-- %%
CREATE OR REPLACE TABLE intellibi_catalog.intellibi_gold.refinedMonthlySales
(
    Customer_ID STRING,
    Customer_Name STRING,
    Gender STRING,
    Age INTEGER,
    City STRING,
    custpurPrice INTEGER,
    purchase_date DATE,
    intial_load_ts TIMESTAMP,
    last_update_ts TIMESTAMP
);

-- describe intellibicatalogo.intellibi_silver.cleanedMonthlySales;
-- describe history intellibicatalogo.intellibi_silver.cleanedMonthlySales;
-- select * from intellibicatalogo.intellibi_gold.refinedMonthlySales;
-- drop table intellibicatalogo.intellibi_silver.cleanedMonthlySales;
-- TRUNCATE TABLE intellibicatalogo.intellibi_silver.cleanedMonthlySales;
-- drop table intellibicatalogo.intellibi_silver.dfmonthlysales;
-- select * from intellibicatalogo.intellibi_silver.dfmonthlysales;
