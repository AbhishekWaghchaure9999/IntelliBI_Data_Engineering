-- %%
CREATE OR REPLACE TABLE intellibicatalogo.intellibi_bronze.rawMonthlySales
(
Customer_ID string,
 Customer_Name string,
 Gender string,
 Age integer,
 City string,
 custpurPrice string,
 purchase_date string,
 ingest_ts timestamp
);
-- TRUNCATE TABLE intellibicatalogo.intellibi_bronze.rawMonthlySales;
-- describe intellibicatalogo.intellibi_bronze.rawMonthlySales;
-- describe history intellibicatalogo.intellibi_bronze.rawMonthlySales;
-- select * from intellibicatalogo.intellibi_bronze.rawMonthlySales;
-- drop table intellibicatalogo.intellibi_bronze.dfMonthlySales;
