-- %%
-- CREATE OR REPLACE TABLE intellibi_catalog.intellibi_bronze.rawPersons
-- (
--     person_name string,
--     age string,
--     gender string,
--     city string,
--     ingest_ts timestamp
-- );

select * from intellibi_catalog.intellibi_bronze.rawPersons;

-- TRUNCATE TABLE intellibi_catalog.intellibi_bronze.rawPersons;
-- describe intellibi_catalog.intellibi_bronze.rawPersons;
-- describe history intellibi_catalog.intellibi_bronze.rawPersons;
-- drop table intellibi_catalog.intellibi_bronze.rawPerson;
