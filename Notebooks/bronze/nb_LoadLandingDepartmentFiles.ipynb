# %%
dfDepartment = spark.read.format("csv").option("header", "true").load("/Volumes/intellibicatalogo/intellibi_schema/intellibi_load_files/CustDetails.csv")
display(dfDepartment)

# %%
dfDepartment1 = spark.read.format("csv").option("header", "true").load("/Volumes/intellibicatalogo/intellibi_schema/intellibi_load_files/AgentDetails.csv")
display(dfDepartment1)
